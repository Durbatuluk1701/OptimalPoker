# %%
set = {(1, 35, 31, 45, 14), (6, 1, 35, 45, 30), (6, 1, 45, 30, 14), (6, 1, 35, 30, 14), (1, 35, 45, 30, 14), (35, 31, 45, 30, 14), (6, 1, 31, 30, 14), (6, 1, 31, 45, 30), (6, 35, 31, 45, 30), (6, 1, 35, 45, 14), (6, 35, 31, 30, 14), (6, 35, 45, 30, 14), (6, 1, 31, 45, 14), (6, 1, 35, 31, 30), (6, 31, 45, 30, 14), (6, 35, 31, 45, 14), (6, 1, 35, 31, 45), (6, 1, 35, 31, 14), (1, 35, 31, 30, 14), (1, 35, 31, 45, 30), (1,31, 45, 30, 14)}

# %%
exec(open("utils.py").read())
exec(open("hands.py").read())

# %%
hand = [23, 47, 43, 41, 17]
print_int_hand(hand)
RankHand(hand)
# Out:
# Queen of Spades
# 10 of Spades
# 6 of Spades
# 4 of Diamonds
# 6 of Diamonds
# 8407682

# %%
DecodeHand(3323372)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18120/1702248406.py in <module>
# ----> 1 DecodeHand(3323372)
#
# <string> in DecodeHand(handCode)
#
# <string> in <listcomp>(.0)
#
# d:\repos2\OptimalPoker\utils.py in val_to_str(val)
#     164
#     165 def val_to_str(val : int):
# --> 166     return reverse_val_trans[val]
#     167
#     168 def suit_to_string(suit : str):
#
# KeyError: 14

# %%
for item in set:
    hand = list(item)
    print_int_hand(hand)
    handVal = RankHand(hand)
    print(handVal)
    print("\n\n\n")
# Out:
# 8 of Hearts
# 3 of Diamonds
# 7 of Spades
# 8 of Diamonds
# 3 of Hearts
# 16778773
#
#
#
#
# 8 of Hearts
# 3 of Diamonds
# Jack of Spades
# 7 of Spades
# 6 of Hearts
# 2358881
#
#
#
#
# 8 of Hearts
# 7 of Spades
# 8 of Diamonds
# 6 of Hearts
# 3 of Hearts
# 8414529
#
#
#
#
# 3 of Diamonds
# Jack of Spades
# 7 of Spades
# 8 of Diamonds
# 3 of Hearts
# 8395109
#
#
#
#
# 8 of Hearts
# 3 of Diamonds
# Jack of Spades
# 8 of Diamonds
# 6 of Hearts
# 8415553
#
#
#
#
# 8 of Hearts
# Jack of Spades
# 7 of Spades
# 8 of Diamonds
# 3 of Hearts
# 8415569
#
#
#
#
# 8 of Hearts
# 3 of Diamonds
# 8 of Diamonds
# 6 of Hearts
# 3 of Hearts
# 16778772
#
#
#
#
# 8 of Hearts
# 3 of Diamonds
# Jack of Spades
# 6 of Hearts
# 3 of Hearts
# 8395108
#
#
#
#
# 8 of Hearts
# 3 of Diamonds
# Jack of Spades
# 7 of Spades
# 8 of Diamonds
# 8415569
#
#
#
#
# 3 of Diamonds
# Jack of Spades
# 8 of Diamonds
# 6 of Hearts
# 3 of Hearts
# 8395108
#
#
#
#
# Jack of Spades
# 7 of Spades
# 8 of Diamonds
# 6 of Hearts
# ...
